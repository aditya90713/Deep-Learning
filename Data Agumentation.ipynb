# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %%
img = image.load_img('cat.jpg', target_size=(200,200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
datagen = ImageDataGenerator(
    rotation_range=30,  #angle
    shear_range= 0.2,  #distortion
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2
)

# %%
# converting image into numpy array
img= image.img_to_array(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# rgb image 3
# Out:
# (200, 200, 3)

# %%
# feeding only image so reshape it before
input_batch = img.reshape(1,200,200,3)

# %%
i = 0
# flow used only one image and for lots of image from folder we use flow from directory
for op in datagen.flow(input_batch, batch_size=1, save_to_dir='agu'):
    i+=1
    if i==10:
        break
